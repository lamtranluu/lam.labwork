# %% [markdown]
# # Example about ethical issues with computer applications

# %% [markdown]
# Article: AI’s Secrets Behind That Job Interview: It’s not what you did or who you are but what AI says about you
# Link: https://medium.com/datadriveninvestor/ais-secrets-behind-that-job-interview-it-s-not-what-you-did-or-who-you-are-but-what-ai-says-about-53e9858a64f9
#
# - The article mentioned about the application of computer vision in the recruitment process. There is a big controversial nowaday since some companies are using AI to analyse candidate performance in video interviews.
# - Video interview: it may be offered in a variety of forms — from live interviews conducted by a hiring manager but simultaneously recorded for future audiences, to recorded interviews conducted by the computer program, giving applicants a limited time (e.g., 30 seconds) to record an answer to each question. In any recorded form, these digital hiring platforms use artificial intelligence (“AI”) to analyze an applicant’s answers. AI may be used to analyze facial expressions or eye contact, or even the speed of an individual’s response, in order to evaluate the quality of an applicant’s answers.”
# - Therefore, the controverial is the bias against anyone non-white and, in some cases, not male. The programs are designed to homogenize applicants into what is considered a “traditional” applicant, and those who are not native-English speakers may be scored negatively based on Ai's assessment.

# %% [markdown]
# # Use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %%
# I choosed people on couch
# %matplotlib inline
from IPython.display import Image
Image('/Users/macbook/Desktop/download.png')

# %% [markdown]
# - Evaluation: The model run pretty good, because the image looks like 2 people on the bed, they are checking mobile phone

# %% [markdown]
# # Read this blog article. Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.

# %% [markdown]
# [URL]('https://thedatafrog.com/en/articles/dogs-vs-cats/')

# %% [markdown]
# - 1. Plotting the first picture in each category
# - 2. Indicating the bad images
# - 3. Cleaning images with these ids in dirname
# - 4. Load images with Keras
# - 5. Labeling the data set
# - 6. Split the train and validation sample with Image generatorr data
# - 7. Create Augmentation
# - 8. Using a pre trained model
